# %%
from selenium import webdriver #1.42 starts from index 1140-1179 above team stats ---- next 1.57 starts from index 1250-1289 below team stats
from bs4 import BeautifulSoup
import pandas as pd

# %%
driver = webdriver.Chrome(executable_path='C:/Users/SubankS/Documents/chromedriver.exe')

# %%
name = []
result_1 = []
result_2 = []
result_3 = []
driver.get("https://www.thespike.gg/match/hysteria-lazarus-esports/40013?map=40445&tab=overview")
content = driver.page_source
soup = BeautifulSoup(content)
result_1 = soup.find_all("div", {"class":"single-stat main-area-alt tablestat-f1 number"}) #for ACS HS ECR FB FD for both teams
result_2 = soup.find_all("div", {"class":"single-stat main-area-alt tablestat-f2 number number"}) # KDA for above team
result_3 = soup.find_all("div", {"class":"single-stat main-area-alt tablestat-f2 number"}) # KDA for below team
result_4 = soup.find_all("div", {"class":"single-stat main-area-alt adr tablestat-f1 number"}) # ADR for both team
cnt = 0
for res in result_4:
    print("Index",cnt)
    cnt=cnt+1
    print(res.text)
# Out:
# Index 0
# 191.4
# Index 1
# 113.7
# Index 2
# 123.1
# Index 3
# 100.4
# Index 4
# 65.7
# Index 5
# 63.4
# Index 6
# 38.3
# Index 7
# 46.9
# Index 8
# 39.6
# Index 9
# 20.4
# Index 10
# 128
# Index 11
# 75.4
# Index 12
# 76.2
# Index 13
# 60.8
# Index 14
# 45.3
# Index 15
# 136.8
# Index 16
# 148.6
# Index 17
# 141.5
# Index 18
# 136.4
# Index 19
# 90.5
# Index 20
# 83.2
# Index 21
# 97
# Index 22
# 82.6
# Index 23
# 90.3
# Index 24
# 67.8
# Index 25
# 53.6
# Index 26
# 51.6
# Index 27
# 59
# Index 28
# 46
# Index 29
# 22.7
# Index 30
# 164.2
# Index 31
# 97.2
# Index 32
# 115.1
# Index 33
# 102.7
# Index 34
# 35.9
# Index 35
# 30.6
# Index 36
# 20.1
# Index 37
# 26.6
# Index 38
# 0
# Index 39
# 19.2
# Index 40
# 133.6
# Index 41
# 77.1
# Index 42
# 88.6
# Index 43
# 102.7
# Index 44
# 16.8
# Index 45
# 186.9
# Index 46
# 129
# Index 47
# 147.6
# Index 48
# 135.1
# Index 49
# 101.2
# Index 50
# 165.9
# Index 51
# 98.5
# Index 52
# 109.3
# Index 53
# 122.9
# Index 54
# 95.4
# Index 55
# ...

# %%
KDA_Above_Team = []
KDA_Below_Team = []
ADR_Both_Team = []

for x in range(0,len(result_2)):
    if(result_2[x].text.replace(" ", "").replace("\n", "").split('|') == ['12', '14', '0']):
        KDA_Above_Team.append(result_2[x].text.replace(" ", "").replace("\n", "").split('|'))
        KDA_Above_Team.append(result_2[x+1].text.replace(" ", "").replace("\n", "").split('|'))
        KDA_Above_Team.append(result_2[x+2].text.replace(" ", "").replace("\n", "").split('|'))
        KDA_Above_Team.append(result_2[x+3].text.replace(" ", "").replace("\n", "").split('|'))
        KDA_Above_Team.append(result_2[x+4].text.replace(" ", "").replace("\n", "").split('|'))
        break

for x in range(0,len(result_3)):
    if(result_3[x].text.replace(" ", "").replace("\n", "").split('|') == ['16', '8', '3']):
        KDA_Below_Team.append(result_3[x].text.replace(" ", "").replace("\n", "").split('|'))
        KDA_Below_Team.append(result_3[x+1].text.replace(" ", "").replace("\n", "").split('|'))
        KDA_Below_Team.append(result_3[x+2].text.replace(" ", "").replace("\n", "").split('|'))
        KDA_Below_Team.append(result_3[x+3].text.replace(" ", "").replace("\n", "").split('|'))
        KDA_Below_Team.append(result_3[x+4].text.replace(" ", "").replace("\n", "").split('|'))
        break

for x in range(0,len(result_4)):
    if(result_4[x].text == "164.2" and result_4[x+1].text == "97.2"):
        ADR_Both_Team.append(result_4[x].text)
        ADR_Both_Team.append(result_4[x+1].text)
        ADR_Both_Team.append(result_4[x+2].text)
        ADR_Both_Team.append(result_4[x+3].text)
        ADR_Both_Team.append(result_4[x+4].text)
        ADR_Both_Team.append(result_4[x+15].text)
        ADR_Both_Team.append(result_4[x+16].text)
        ADR_Both_Team.append(result_4[x+17].text)
        ADR_Both_Team.append(result_4[x+18].text)
        ADR_Both_Team.append(result_4[x+19].text)
        
print(KDA_Above_Team)
# Out:
# [['12', '14', '0'], ['9', '13', '3'], ['10', '13', '0'], ['7', '16', '2'], ['2', '13', '2']]

# %%
print(result_2[0].text.replace(" ", "").replace("\n", "").split('|'))
# Out:
# ['22', '13', '3']

# %%
ACS_Above_Team = 0
K_Above_Team = 0
D_Above_Team = 0
A_Above_Team = 0
KD_Above_Team = 0
ADR_Above_Team = 0
HS_Above_Team = 0
ESR_Above_Team = 0
FB_Above_Team = 0
FD_Above_Team = 0

ACS_Below_Team = 0
K_Below_Team = 0
D_Below_Team = 0
A_Below_Team = 0
KD_Below_Team = 0
ADR_Below_Team = 0
HS_Below_Team = 0
ESR_Below_Team = 0
FB_Below_Team = 0
FD_Below_Team = 0

print("Rating",'\t',"ACS",'\t',"K",'\t',"D",'\t',"A",'\t',"+/-",'\t',"K/D",'\t',"ADR",'\t',"HS",'\t',"ESR",'\t',"FB",'\t',"FD",'\n')

for x in range(0,len(result_1)):
    if(result_1[x].text=="0.93" and result_1[x+1].text=="229"):
        print("Above Team Stats")
        print(result_1[x].text,'\t',result_1[x+1].text,'\t',KDA_Above_Team[0][0],'\t',KDA_Above_Team[0][1],'\t',KDA_Above_Team[0][2],'\t',result_1[x+2].text,'\t',result_1[x+3].text,'\t',ADR_Both_Team[0],'\t',result_1[x+4].text,'\t',result_1[x+5].text,'\t',result_1[x+6].text,'\t',result_1[x+7].text)
        print(result_1[x+8].text,'\t',result_1[x+9].text,'\t',KDA_Above_Team[1][0],'\t',KDA_Above_Team[1][1],'\t',KDA_Above_Team[1][2],'\t',result_1[x+10].text,'\t',result_1[x+11].text,'\t',ADR_Both_Team[1],'\t',result_1[x+12].text,'\t',result_1[x+13].text,'\t',result_1[x+14].text,'\t',result_1[x+15].text)
        print(result_1[x+16].text,'\t',result_1[x+17].text,'\t',KDA_Above_Team[2][0],'\t',KDA_Above_Team[2][1],'\t',KDA_Above_Team[2][2],'\t',result_1[x+18].text,'\t',result_1[x+19].text,'\t',ADR_Both_Team[2],'\t',result_1[x+20].text,'\t',result_1[x+21].text,'\t',result_1[x+22].text,'\t',result_1[x+23].text)
        print(result_1[x+24].text,'\t',result_1[x+25].text,'\t',KDA_Above_Team[3][0],'\t',KDA_Above_Team[3][1],'\t',KDA_Above_Team[3][2],'\t',result_1[x+26].text,'\t',result_1[x+27].text,'\t',ADR_Both_Team[3],'\t',result_1[x+28].text,'\t',result_1[x+29].text,'\t',result_1[x+30].text,'\t',result_1[x+31].text)
        print(result_1[x+32].text,'\t',result_1[x+33].text,'\t',KDA_Above_Team[4][0],'\t',KDA_Above_Team[4][1],'\t',KDA_Above_Team[4][2],'\t',result_1[x+34].text,'\t',result_1[x+35].text,'\t',ADR_Both_Team[4],'\t',result_1[x+36].text,'\t',result_1[x+37].text,'\t',result_1[x+38].text,'\t',result_1[x+39].text)
        ACS_Above_Team = (int(result_1[x+1].text)+int(result_1[x+9].text)+int(result_1[x+17].text)+int(result_1[x+25].text)+int(result_1[x+33].text))/5
        K_Above_Team = (int(KDA_Above_Team[0][0])+int(KDA_Above_Team[1][0])+int(KDA_Above_Team[2][0])+int(KDA_Above_Team[3][0])+int(KDA_Above_Team[4][0]))/5
        D_Above_Team = (int(KDA_Above_Team[0][1])+int(KDA_Above_Team[1][1])+int(KDA_Above_Team[2][1])+int(KDA_Above_Team[3][1])+int(KDA_Above_Team[4][1]))/5
        A_Above_Team = (int(KDA_Above_Team[0][2])+int(KDA_Above_Team[1][2])+int(KDA_Above_Team[2][2])+int(KDA_Above_Team[3][2])+int(KDA_Above_Team[4][2]))/5
        KD_Above_Team = round((K_Above_Team/D_Above_Team),3)
        ADR_Above_Team = round((float(ADR_Both_Team[0])+float(ADR_Both_Team[1])+float(ADR_Both_Team[2])+float(ADR_Both_Team[3])+float(ADR_Both_Team[4]))/5,3)
        HS_Above_Team = (int(result_1[x+4].text.replace("%",""))+int(result_1[x+12].text.replace("%",""))+int(result_1[x+20].text.replace("%",""))+int(result_1[x+28].text.replace("%",""))+int(result_1[x+36].text.replace("%","")))/5
        ESR_Above_Team = (int(result_1[x+5].text.replace("%",""))+int(result_1[x+13].text.replace("%",""))+int(result_1[x+21].text.replace("%",""))+int(result_1[x+29].text.replace("%",""))+int(result_1[x+37].text.replace("%","")))/5
        FB_Above_Team = (int(result_1[x+6].text)+int(result_1[x+14].text)+int(result_1[x+22].text)+int(result_1[x+30].text)+int(result_1[x+38].text))/5
        FD_Above_Team = (int(result_1[x+7].text)+int(result_1[x+15].text)+int(result_1[x+23].text)+int(result_1[x+31].text)+int(result_1[x+39].text))/5
        
        print("Below Team Stats")
        print(result_1[x+110].text,'\t',result_1[x+111].text,'\t',KDA_Below_Team[0][0],'\t',KDA_Below_Team[0][1],'\t',KDA_Below_Team[0][2],'\t',result_1[x+112].text,'\t',result_1[x+113].text,'\t',ADR_Both_Team[5],'\t',result_1[x+114].text,'\t',result_1[x+115].text,'\t',result_1[x+116].text,'\t',result_1[x+117].text)
        print(result_1[x+118].text,'\t',result_1[x+119].text,'\t',KDA_Below_Team[1][0],'\t',KDA_Below_Team[1][1],'\t',KDA_Below_Team[1][2],'\t',result_1[x+120].text,'\t',result_1[x+121].text,'\t',ADR_Both_Team[6],'\t',result_1[x+122].text,'\t',result_1[x+123].text,'\t',result_1[x+124].text,'\t',result_1[x+125].text)
        print(result_1[x+126].text,'\t',result_1[x+127].text,'\t',KDA_Below_Team[2][0],'\t',KDA_Below_Team[2][1],'\t',KDA_Below_Team[2][2],'\t',result_1[x+128].text,'\t',result_1[x+129].text,'\t',ADR_Both_Team[7],'\t',result_1[x+130].text,'\t',result_1[x+131].text,'\t',result_1[x+132].text,'\t',result_1[x+133].text)
        print(result_1[x+134].text,'\t',result_1[x+135].text,'\t',KDA_Below_Team[3][0],'\t',KDA_Below_Team[3][1],'\t',KDA_Below_Team[3][2],'\t',result_1[x+136].text,'\t',result_1[x+137].text,'\t',ADR_Both_Team[8],'\t',result_1[x+138].text,'\t',result_1[x+139].text,'\t',result_1[x+140].text,'\t',result_1[x+141].text)
        print(result_1[x+142].text,'\t',result_1[x+143].text,'\t',KDA_Below_Team[4][0],'\t',KDA_Below_Team[4][1],'\t',KDA_Below_Team[4][2],'\t',result_1[x+144].text,'\t',result_1[x+145].text,'\t',ADR_Both_Team[9],'\t',result_1[x+146].text,'\t',result_1[x+147].text,'\t',result_1[x+148].text,'\t',result_1[x+149].text)
        ACS_Below_Team = (int(result_1[x+111].text)+int(result_1[x+119].text)+int(result_1[x+127].text)+int(result_1[x+135].text)+int(result_1[x+143].text))/5
        K_Below_Team = (int(KDA_Below_Team[0][0])+int(KDA_Below_Team[1][0])+int(KDA_Below_Team[2][0])+int(KDA_Below_Team[3][0])+int(KDA_Below_Team[4][0]))/5
        D_Below_Team = (int(KDA_Below_Team[0][1])+int(KDA_Below_Team[1][1])+int(KDA_Below_Team[2][1])+int(KDA_Below_Team[3][1])+int(KDA_Below_Team[4][1]))/5
        A_Below_Team = (int(KDA_Below_Team[0][2])+int(KDA_Below_Team[1][2])+int(KDA_Below_Team[2][2])+int(KDA_Below_Team[3][2])+int(KDA_Below_Team[4][2]))/5
        KD_Below_Team = round((K_Below_Team/D_Below_Team),3)
        ADR_Below_Team = round((float(ADR_Both_Team[5])+float(ADR_Both_Team[6])+float(ADR_Both_Team[7])+float(ADR_Both_Team[8])+float(ADR_Both_Team[9]))/5,3)
        HS_Below_Team = (int(result_1[x+114].text.replace("%",""))+int(result_1[x+122].text.replace("%",""))+int(result_1[x+130].text.replace("%",""))+int(result_1[x+138].text.replace("%",""))+int(result_1[x+146].text.replace("%","")))/5
        ESR_Below_Team = (int(result_1[x+115].text.replace("%",""))+int(result_1[x+123].text.replace("%",""))+int(result_1[x+131].text.replace("%",""))+int(result_1[x+139].text.replace("%",""))+int(result_1[x+147].text.replace("%","")))/5
        FB_Below_Team = (int(result_1[x+116].text)+int(result_1[x+124].text)+int(result_1[x+132].text)+int(result_1[x+140].text)+int(result_1[x+148].text))/5
        FD_Below_Team = (int(result_1[x+117].text)+int(result_1[x+125].text)+int(result_1[x+133].text)+int(result_1[x+141].text)+int(result_1[x+149].text))/5
        break
        
print("\n------------\n")
print("Above Team Stats")
print(ACS_Above_Team,'\t',K_Above_Team,'\t',D_Above_Team,'\t',A_Above_Team,'\t',KD_Above_Team,'\t',ADR_Above_Team,'\t\t',HS_Above_Team,'\t',ESR_Above_Team,'\t',FB_Above_Team,'\t',FD_Above_Team)
print("Below Team Stats")
print(ACS_Below_Team,'\t',K_Below_Team,'\t',D_Below_Team,'\t',A_Below_Team,'\t',KD_Below_Team,'\t',ADR_Below_Team,'\t',HS_Below_Team,'\t',ESR_Below_Team,'\t',FB_Below_Team,'\t',FD_Below_Team)
# Out:
# Rating 	 ACS 	 K 	 D 	 A 	 +/- 	 K/D 	 ADR 	 HS 	 ESR 	 FB 	 FD
#
# Above Team Stats
# 0.93 	 229 	 12 	 14 	 0 	 -2 	 0.86 	 164.2 	 17% 	 100% 	 3 	 0
# 0.76 	 170 	 9 	 13 	 3 	 -4 	 0.69 	 97.2 	 21% 	 0% 	 0 	 1
# 0.70 	 200 	 10 	 13 	 0 	 -3 	 0.77 	 115.1 	 26% 	 0% 	 0 	 2
# 0.52 	 148 	 7 	 16 	 2 	 -9 	 0.44 	 102.7 	 24% 	 44% 	 4 	 5
# 0.13 	 51 	 2 	 13 	 2 	 -11 	 0.15 	 35.9 	 14% 	 0% 	 0 	 1
# Below Team Stats
# 1.35 	 299 	 16 	 8 	 3 	 +8 	 2 	 186.9 	 27% 	 100% 	 2 	 0
# 1.26 	 220 	 16 	 6 	 1 	 +10 	 2.67 	 129 	 34% 	 100% 	 3 	 0
# 1.22 	 247 	 14 	 10 	 6 	 +4 	 1.4 	 147.6 	 17% 	 67% 	 2 	 1
# 1.20 	 230 	 16 	 7 	 1 	 +9 	 2.29 	 135.1 	 37% 	 0% 	 0 	 2
# 0.63 	 146 	 7 	 9 	 5 	 -2 	 0.78 	 101.2 	 17% 	 33% 	 2 	 4
#
# ------------
#
# Above Team Stats
# 159.6 	 8.0 	 13.8 	 1.4 	 0.58 	 103.02 		 20.4 	 28.8 	 1.4 	 1.8
# Below Team Stats
# 228.4 	 13.8 	 8.0 	 3.2 	 1.725 	 139.96 	 26.4 	 60.0 	 1.8 	 1.4

# %%
for x in range(0,len(result_2)):
    if(result_2[x].text.replace(" ", "").replace("\n", "").split('|') == ['20', '13', '2']):
        print(result_2[x].text.replace(" ", "").replace("\n", "").split('|'))
        print(result_2[x+1].text.replace(" ", "").replace("\n", "").split('|'))
        print(result_2[x+2].text.replace(" ", "").replace("\n", "").split('|'))
        print(result_2[x+3].text.replace(" ", "").replace("\n", "").split('|'))
        print(result_2[x+4].text.replace(" ", "").replace("\n", "").split('|'))
        break
# Out:
# ['20', '13', '2']
# ['17', '13', '6']
# ['15', '13', '7']
# ['14', '14', '5']
# ['13', '16', '1']

# %%
for x in range(0,len(result_3)):
    if(result_3[x].text.replace(" ", "").replace("\n", "").split('|') == ['19', '17', '3']):
        print(result_3[x].text.replace(" ", "").replace("\n", "").split('|'))
        print(result_3[x+1].text.replace(" ", "").replace("\n", "").split('|'))
        print(result_3[x+2].text.replace(" ", "").replace("\n", "").split('|'))
        print(result_3[x+3].text.replace(" ", "").replace("\n", "").split('|'))
        print(result_3[x+4].text.replace(" ", "").replace("\n", "").split('|'))
        break
# Out:
# ['19', '17', '3']
# ['16', '14', '2']
# ['14', '14', '6']
# ['11', '17', '6']
# ['9', '17', '7']

# %%
for x in range(0,len(result_4)):
    if(result_4[x].text == "141.6" and result_4[x+1].text == "141.6"):
        print(result_4[x].text,result_4[x+1].text,result_4[x+2].text,result_4[x+3].text,result_4[x+4].text)
        print(result_4[x+15].text,result_4[x+16].text,result_4[x+17].text,result_4[x+18].text,result_4[x+19].text)
# Out:
# 141.6 141.6 154.4 115.3 90.4
# 134.1 132.7 148.4 101 90.1
